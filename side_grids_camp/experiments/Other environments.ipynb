# %%
import os
from IPython import display

os.chdir("../gifs")


display.Image("env_taxonomy.png", width=1000, height=1000)

# %%
display.Image("go_away.png", width=500, height=500)

# %%
# Burning buildings
display.Image("libertarian.png", width=500, height=500)

# %%
display.Image("expected.png", width=500, height=500)

# %%
display.Image("stomp.png", width=400, height=400)

# %%
display.Image("dodge.png", width=400, height=400)
